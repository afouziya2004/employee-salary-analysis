# %% [markdown]
# <a href="https://colab.research.google.com/github/afouziya2004/employee-salary-analysis/blob/notebooks/employee_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\user\Desktop\ff\data\employee.csv")
df.head()
# Out:
#    EmployeeID     Name Department       Role  Salary  PerformanceRating  \
# 0         101    Alice         IT  Developer   85000                  4
# 1         102      Bob         HR    Manager   75000                  3
# 2         103  Charlie    Finance    Analyst   65000                  4
# 3         104    David         IT  Developer   90000                  5
# 4         105      Eva    Finance    Analyst   62000                  2
#
#    ExperienceYears
# 0                5
# 1                8
# 2                4
# 3                7
# 4                3

# %%
df.groupby("Department")["Salary"].mean()
df[df["PerformanceRating"] >= 4]
# Out:
#    EmployeeID     Name Department       Role  Salary  PerformanceRating  \
# 0         101    Alice         IT  Developer   85000                  4
# 2         103  Charlie    Finance    Analyst   65000                  4
# 3         104    David         IT  Developer   90000                  5
# 6         107    Grace         IT     Tester   60000                  4
# 7         108    Helen    Finance    Manager   95000                  5
# 8         109      Ian         IT  Architect  120000                  5
# 9         110     Judy         HR    Manager   80000                  4
#
#    ExperienceYears
# 0                5
# 2                4
# 3                7
# 6                4
# 7               10
# 8               12
# 9                9

# %%
import matplotlib.pyplot as plt

df.groupby("Department")["Salary"].mean().plot(kind="bar")
plt.title("Average Salary by Department")
plt.show()
plt.savefig(r"C:\Users\user\Desktop\ff\visuals\Average_salary_plots.png")
